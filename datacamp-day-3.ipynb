# %%
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/datacamp-day-3-assignment/bios_toy.csv")

# %%
df
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       athlete_id                 name   born_date        born_city  height_cm  \
# 0          75624        David Sawyerr  1961-05-06              NaN      170.0
# 1         102742          Kim Chi-Gon  1983-07-29            Busan      183.0
# 2         120347  Yelena Danilochkina  1986-01-27  Moskva (Moscow)      183.0
# 3          97196       Franck Saunier  1966-02-14              Gap      175.0
# ...

# %%
df.shape
# Out:
# (10000, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   athlete_id  10000 non-null  int64
#  1   name        10000 non-null  object
#  2   born_date   9882 non-null   object
#  3   born_city   7631 non-null   object
#  4   height_cm   7365 non-null   float64
#  5   weight_kg   7022 non-null   float64
#  6   died_date   2308 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 547.0+ KB

# %%
df.isnull().sum()
# Out:
# athlete_id       0
# name             0
# born_date      118
# born_city     2369
# height_cm     2635
# weight_kg     2978
# died_date     7692
# dtype: int64

# %%
df.shape
# Out:
# (10000, 7)

# %%
temp = df[~df['born_date'].isna()]
temp
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       athlete_id                 name   born_date        born_city  height_cm  \
# 0          75624        David Sawyerr  1961-05-06              NaN      170.0
# 1         102742          Kim Chi-Gon  1983-07-29            Busan      183.0
# 2         120347  Yelena Danilochkina  1986-01-27  Moskva (Moscow)      183.0
# 3          97196       Franck Saunier  1966-02-14              Gap      175.0
# ...

# %%
temp = df[~df['born_city'].isna()]
temp
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       athlete_id                 name   born_date        born_city  height_cm  \
# 1         102742          Kim Chi-Gon  1983-07-29            Busan      183.0
# 2         120347  Yelena Danilochkina  1986-01-27  Moskva (Moscow)      183.0
# 3          97196       Franck Saunier  1966-02-14              Gap      175.0
# 4          53305            Butch May  1941-11-07         Honolulu      183.0
# ...

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7631 entries, 1 to 9999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   athlete_id  7631 non-null   int64
#  1   name        7631 non-null   object
#  2   born_date   7628 non-null   object
#  3   born_city   7631 non-null   object
#  4   height_cm   5929 non-null   float64
#  5   weight_kg   5644 non-null   float64
#  6   died_date   1962 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 476.9+ KB

# %%
temp.describe()
# Out:
#           athlete_id    height_cm    weight_kg
# count    7631.000000  5929.000000  5644.000000
# mean    74939.086882   176.926126    72.701630
# std     42581.135015    10.495996    14.602765
# min         8.000000   133.000000    28.000000
# 25%     37345.000000   170.000000    63.000000
# 50%     77531.000000   177.000000    72.000000
# 75%    112296.500000   184.000000    81.000000
# max    149190.000000   221.000000   156.000000

# %%
weight_mean = temp['weight_kg'].mean()

# %%
temp['weight_kg']
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# 1        75.0
# 2        70.0
# 3        76.0
# 4        84.0
# 5         NaN
#         ...
# 9994    105.0
# 9995      NaN
# 9997     63.0
# 9998     54.0
# 9999     46.0
# Name: weight_kg, Length: 7631, dtype: float64

# %%
temp['weight_kg'] = temp['weight_kg'].fillna(weight_mean)
# Out:
# /tmp/ipykernel_47/2723603468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['weight_kg'] = temp['weight_kg'].fillna(weight_mean)

# %%
height_mean = temp['height_cm'].mean()
temp['height_cm'] = temp['height_cm'].fillna(height_mean)
# Out:
# /tmp/ipykernel_47/2876032537.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['height_cm'] = temp['height_cm'].fillna(height_mean)

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7631 entries, 1 to 9999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   athlete_id  7631 non-null   int64
#  1   name        7631 non-null   object
#  2   born_date   7628 non-null   object
#  3   born_city   7631 non-null   object
#  4   height_cm   7631 non-null   float64
#  5   weight_kg   7631 non-null   float64
#  6   died_date   1962 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 476.9+ KB

# %%
temp = temp.drop(columns=['died_date'])

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7631 entries, 1 to 9999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   athlete_id  7631 non-null   int64
#  1   name        7631 non-null   object
#  2   born_date   7628 non-null   object
#  3   born_city   7631 non-null   object
#  4   height_cm   7631 non-null   float64
#  5   weight_kg   7631 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 417.3+ KB

# %%
temp.isnull().sum()
# Out:
# athlete_id    0
# name          0
# born_date     0
# born_city     0
# height_cm     0
# weight_kg     0
# dtype: int64

# %%
temp = temp[~temp['born_date'].isnull()]
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7628 entries, 1 to 9999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   athlete_id  7628 non-null   int64
#  1   name        7628 non-null   object
#  2   born_date   7628 non-null   object
#  3   born_city   7628 non-null   object
#  4   height_cm   7628 non-null   float64
#  5   weight_kg   7628 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 417.2+ KB

# %%
temp['born_date'] = pd.to_datetime(temp["born_date"])
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7628 entries, 1 to 9999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   athlete_id  7628 non-null   int64
#  1   name        7628 non-null   object
#  2   born_date   7628 non-null   datetime64[ns]
#  3   born_city   7628 non-null   object
#  4   height_cm   7628 non-null   float64
#  5   weight_kg   7628 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 417.2+ KB

# %%
import matplotlib.pyplot as plt 

plt.hist(temp['height_cm'])
plt.show()

# %%
import matplotlib.pyplot as plt 

plt.hist(temp['weight_kg'])
plt.show()

# %%
temp.head()
# Out:
#    athlete_id                 name  born_date        born_city  height_cm  \
# 1      102742          Kim Chi-Gon 1983-07-29            Busan      183.0
# 2      120347  Yelena Danilochkina 1986-01-27  Moskva (Moscow)      183.0
# 3       97196       Franck Saunier 1966-02-14              Gap      175.0
# 4       53305            Butch May 1941-11-07         Honolulu      183.0
# 5      143316        Leonie Menzel 1999-05-19         Mettmann      175.0
#
#    weight_kg
# 1   75.00000
# 2   70.00000
# 3   76.00000
# 4   84.00000
# 5   72.70163

# %%
temp['first_name'] = temp['name'].str.split().str[0]
temp['first_name']
# Out:
# 1             Kim
# 2          Yelena
# 3          Franck
# 4           Butch
# 5          Leonie
#           ...
# 9994       Walter
# 9995       Ovidio
# 9997    Stephanie
# 9998      Vanessa
# 9999        Leila
# Name: first_name, Length: 7628, dtype: object

# %%
dd = temp[(temp['height_cm'] > 160) & (temp['weight_kg'] < 80)]
dd
# Out:
#       athlete_id                 name  born_date        born_city   height_cm  \
# 1         102742          Kim Chi-Gon 1983-07-29            Busan  183.000000
# 2         120347  Yelena Danilochkina 1986-01-27  Moskva (Moscow)  183.000000
# 3          97196       Franck Saunier 1966-02-14              Gap  175.000000
# 5         143316        Leonie Menzel 1999-05-19         Mettmann  175.000000
# 7          82969     Dubravka Vukušić 1965-12-22           Zagreb  176.926126
# ...          ...                  ...        ...              ...         ...
# 9988       12209     Petrus Kastenman 1924-08-15          Bälinge  176.926126
# 9989       96510        Jože Poklukar 1973-01-30         Jesenice  181.000000
# 9993       42056      Vilho Vauhkonen 1877-02-06       Pieksämäki  176.926126
# 9995       62693         Ovidio Lagos 1912-07-21            Merlo  176.926126
# 9997      120378       Stephanie Vogt 1990-02-15            Vaduz  165.000000
#
#       weight_kg first_name
# ...

# %%
today = 2025
temp['Age'] = (today - temp['born_date'].dt.year)

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7628 entries, 1 to 9999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   athlete_id  7628 non-null   int64
#  1   name        7628 non-null   object
#  2   born_date   7628 non-null   datetime64[ns]
#  3   born_city   7628 non-null   object
#  4   height_cm   7628 non-null   float64
#  5   weight_kg   7628 non-null   float64
#  6   first_name  7628 non-null   object
#  7   Age         7628 non-null   int32
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(1), object(3)
# memory usage: 764.6+ KB

# %%
temp
# Out:
#       athlete_id                 name  born_date        born_city   height_cm  \
# 1         102742          Kim Chi-Gon 1983-07-29            Busan  183.000000
# 2         120347  Yelena Danilochkina 1986-01-27  Moskva (Moscow)  183.000000
# 3          97196       Franck Saunier 1966-02-14              Gap  175.000000
# 4          53305            Butch May 1941-11-07         Honolulu  183.000000
# 5         143316        Leonie Menzel 1999-05-19         Mettmann  175.000000
# ...          ...                  ...        ...              ...         ...
# 9994      108477      Walter Herrmann 1979-06-26    Venado Tuerto  203.000000
# 9995       62693         Ovidio Lagos 1912-07-21            Merlo  176.926126
# 9997      120378       Stephanie Vogt 1990-02-15            Vaduz  165.000000
# 9998      101854      Vanessa Giunchi 1980-06-07           Milano  157.000000
# 9999      129917      Leila Abdelmoez 1996-09-30  Al-Jizah (Giza)  160.000000
#
#       weight_kg first_name  Age
# ...

# %%
temp = temp.sort_values(by="born_date")

# %%
temp
# Out:
#       athlete_id                  name  born_date   born_city   height_cm  \
# 1055       12478  Georges Nagelmackers 1845-06-24       Liège  176.926126
# 9467        2249         Will Thompson 1848-03-10     Calhoun  176.926126
# 2930        2227        Amos Casselman 1850-11-14      Canton  176.926126
# 613          567      Robert Backhouse 1854-03-10  Darlington  176.926126
# 875        18139           Mary Abbott 1857-10-17       Salem  176.926126
# ...          ...                   ...        ...         ...         ...
# 9971      139296             Kate Wang 2005-03-31     Lansing  176.926126
# 8693      139358       Nicolò Remolato 2005-06-08     Bolzano  176.926126
# 6119      141407           Ava Stewart 2005-09-30     Lebanon  176.926126
# 6492      139561          Alizee Aymon 2005-11-22      Icogne  176.926126
# 1992      141168           Rayssa Leal 2008-01-04  Imperatriz  147.000000
#
#       weight_kg first_name  Age
# 1055   72.70163    Georges  180
# ...
